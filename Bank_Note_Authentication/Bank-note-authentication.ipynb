# %% [markdown]
# Dataset link : https://www.kaggle.com/datasets/ritesaluja/bank-note-authentication-uci-data/data

# %% [markdown]
# In this notebook, classfication of bank notes as Original(1) or Duplicate(0) is done on the basis of different feature like Variance,  Skewness, Curtosis, Entropy.

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 

from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC 
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
data = pd.read_csv('BankNote_Authentication.csv') 
data.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
data['class'].value_counts()
# Out:
# class
# 0    762
# 1    610
# Name: count, dtype: int64

# %%
print(f'Shape of data : {data.shape}')
print(f'Null values in the data : {data.isnull().sum().sum()}')
# Out:
# Shape of data : (1372, 5)
# Null values in the data : 0

# %%
data.describe()
# Out:
#           variance     skewness     curtosis      entropy        class
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean      0.433735     1.922353     1.397627    -1.191657     0.444606
# std       2.842763     5.869047     4.310030     2.101013     0.497103
# min      -7.042100   -13.773100    -5.286100    -8.548200     0.000000
# 25%      -1.773000    -1.708200    -1.574975    -2.413450     0.000000
# 50%       0.496180     2.319650     0.616630    -0.586650     0.000000
# 75%       2.821475     6.814625     3.179250     0.394810     1.000000
# max       6.824800    12.951600    17.927400     2.449500     1.000000

# %%
# Checking the distribution of data
ax = data.hist(figsize=(20,10))
plt.show()

# %%
# Checking outliers
ax = data.boxplot(figsize=(20,10)) 
ax.set_title('Outlier Detection') 
plt.show()

# %%
# Check if data is balanced or imbalanced
ax = data['class'].value_counts().plot(kind='bar') 
plt.show()

# %%
# Checking correltaion among features
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(),annot=True) 
plt.show()
